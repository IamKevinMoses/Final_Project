# %%
#Just to check things later delete this
import joblib

package = joblib.load("../models/final_logistic_regression_package.pkl")

print(type(package["scaler"]))
print(type(package["model"]))
print(package["feature_names"][:10])
# Out:
# <class 'sklearn.preprocessing._data.StandardScaler'>
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# ['year', 'contaminant_level', 'ph', 'turbidity', 'dissolved_oxygen', 'nitrate', 'lead', 'bacteria_count', 'clean_water_access', 'infant_mortality_rate']

# %%
print("Saved feature count:", len(package["feature_names"]))
print("Scaler feature count:", package["scaler"].n_features_in_)

print(
    package["feature_names"]
    == package["scaler"].feature_names_in_.tolist()
)
# Out:
# Saved feature count: 38
# Scaler feature count: 38
# True
