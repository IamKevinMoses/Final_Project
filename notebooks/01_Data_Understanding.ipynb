# %%
#Import Libraries
import pandas as pd
import numpy as np

# %%
#Load the dataset
df = pd.read_csv("C:/Users/Kevin.Moses/Desktop/ICBT Assignments/1. New Batch Assignments/Final Project/Final_Project/data/raw/water_pollution_disease.csv")

# %%
#Display First Rows
df.head()
# Out:
#      Country   Region  Year Water Source Type  Contaminant Level (ppm)  \
# 0     Mexico    North  2015              Lake                     1.04
# 1     Brazil     West  2017              Well                     2.48
# 2  Indonesia  Central  2022              Pond                     3.38
# 3    Nigeria     East  2016              Well                     2.50
# 4     Mexico    South  2005              Well                     0.73
#
#    pH Level  Turbidity (NTU)  Dissolved Oxygen (mg/L)  Nitrate Level (mg/L)  \
# 0      6.88             0.15                     9.38                 10.91
# 1      7.26             1.06                     6.73                 21.71
# 2      7.58             7.03                     4.67                 22.55
# 3      6.86             2.40                     7.88                 16.29
# 4      6.52             2.24                     7.80                  8.91
#
#    Lead Concentration (µg/L)  ...  Cholera Cases per 100,000 people  \
# ...

# %%
#Dataset Shape
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (3000, 24)

# %%
#Column Names  
df.columns
# Out:
# Index(['Country', 'Region', 'Year', 'Water Source Type',
#        'Contaminant Level (ppm)', 'pH Level', 'Turbidity (NTU)',
#        'Dissolved Oxygen (mg/L)', 'Nitrate Level (mg/L)',
#        'Lead Concentration (µg/L)', 'Bacteria Count (CFU/mL)',
#        'Water Treatment Method', 'Access to Clean Water (% of Population)',
#        'Diarrheal Cases per 100,000 people',
#        'Cholera Cases per 100,000 people', 'Typhoid Cases per 100,000 people',
#        'Infant Mortality Rate (per 1,000 live births)', 'GDP per Capita (USD)',
#        'Healthcare Access Index (0-100)', 'Urbanization Rate (%)',
#        'Sanitation Coverage (% of Population)', 'Rainfall (mm per year)',
#        'Temperature (°C)', 'Population Density (people per km²)'],
#       dtype='str')

# %%
#Dataset Information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Country                                        3000 non-null   str
#  1   Region                                         3000 non-null   str
#  2   Year                                           3000 non-null   int64
#  3   Water Source Type                              3000 non-null   str
#  4   Contaminant Level (ppm)                        3000 non-null   float64
#  5   pH Level                                       3000 non-null   float64
#  6   Turbidity (NTU)                                3000 non-null   float64
#  7   Dissolved Oxygen (mg/L)                        3000 non-null   float64
#  8   Nitrate Level (mg/L)                           3000 non-null   float64
# ...

# %%
#Statistical Summary
df.describe()
# Out:
#               Year  Contaminant Level (ppm)     pH Level  Turbidity (NTU)  \
# count  3000.000000              3000.000000  3000.000000      3000.000000
# mean   2012.012667                 1.972287     7.043397         2.743283
# std       7.229287                 0.961239     0.380709         2.140164
# min    2000.000000                 0.020000     5.700000         0.150000
# 25%    2006.000000                 1.230000     6.790000         1.060000
# 50%    2012.000000                 1.950000     7.050000         2.290000
# 75%    2018.000000                 2.660000     7.300000         4.010000
# max    2024.000000                 5.060000     8.510000        11.430000
#
#        Dissolved Oxygen (mg/L)  Nitrate Level (mg/L)  \
# count              3000.000000           3000.000000
# mean                  7.335710             16.950683
# std                   1.054605              5.792659
# min                   3.970000              2.880000
# ...

# %%
#Missing Values
df.isnull().sum()
# Out:
# Country                                            0
# Region                                             0
# Year                                               0
# Water Source Type                                  0
# Contaminant Level (ppm)                            0
# pH Level                                           0
# Turbidity (NTU)                                    0
# Dissolved Oxygen (mg/L)                            0
# Nitrate Level (mg/L)                               0
# Lead Concentration (µg/L)                          0
# Bacteria Count (CFU/mL)                            0
# Water Treatment Method                           747
# Access to Clean Water (% of Population)            0
# Diarrheal Cases per 100,000 people                 0
# Cholera Cases per 100,000 people                   0
# Typhoid Cases per 100,000 people                   0
# Infant Mortality Rate (per 1,000 live births)      0
# GDP per Capita (USD)                               0
# ...

# %%
#Duplicate Rows
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
#Unique Values
df.nunique()
# Out:
# Country                                            10
# Region                                              5
# Year                                               25
# Water Source Type                                   6
# Contaminant Level (ppm)                           427
# pH Level                                          219
# Turbidity (NTU)                                   728
# Dissolved Oxygen (mg/L)                           490
# Nitrate Level (mg/L)                             1647
# Lead Concentration (µg/L)                         958
# Bacteria Count (CFU/mL)                          1003
# Water Treatment Method                              3
# Access to Clean Water (% of Population)          2186
# Diarrheal Cases per 100,000 people                301
# Cholera Cases per 100,000 people                   32
# Typhoid Cases per 100,000 people                   52
# Infant Mortality Rate (per 1,000 live births)    2387
# ...

# %%
#Random Sample
df.sample(10)
# Out:
#          Country   Region  Year Water Source Type  Contaminant Level (ppm)  \
# 2242    Pakistan    North  2006             River                     2.24
# 741    Indonesia  Central  2003              Lake                     2.70
# 2885      Mexico     East  2005              Pond                     3.70
# 2786   Indonesia    North  2024            Spring                     1.41
# 803     Ethiopia     East  2010              Well                     1.79
# 2205     Nigeria     West  2021            Spring                     1.23
# 1629    Ethiopia     East  2024            Spring                     0.02
# 992   Bangladesh     East  2011              Pond                     3.13
# 2532      Mexico  Central  2022             River                     3.24
# 2258  Bangladesh     West  2011              Well                     2.53
#
#       pH Level  Turbidity (NTU)  Dissolved Oxygen (mg/L)  \
# 2242      6.91             2.84                     7.83
# ...
